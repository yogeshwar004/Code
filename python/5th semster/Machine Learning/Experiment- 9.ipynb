# %%
from sklearn import datasets
op=datasets.fetch_olivetti_faces()
#op
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\Yogeshwar N\scikit_learn_data

# %%
#step2: Linear Points
x=op.data
y=op.target
#x
#y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
#x_train

# %%
from sklearn.naive_bayes import GaussianNB
#step3: Initialize the naive bayes classifier
gnb=GaussianNB()

# %%
#step 4: Train the classifier

gnb.fit(x_train,y_train)
#step 5: predict on test set
y_pred=gnb.predict(x_test)

# %%
#step 6: Compute accuracy
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print(f"Accuracy of Naive Bayes:{acc*100}%")
# Out:
# Accuracy of Naive Bayes:74.16666666666667%

# %%
import matplotlib.pyplot as plt
#Display a few test images with predicted labels
n_samples=10
plt.figure(figsize=(50,10))
for i in range(n_samples):
    ax=plt.subplot(1,n_samples,i+1)
    ax.imshow(x_test[i].reshape(64,64),cmap="gray")
    #ax.set_title(f"Pred:{y_pred[i]}\n True:{y_test[i]}")
    #ax.axis('off')
plt.show()
