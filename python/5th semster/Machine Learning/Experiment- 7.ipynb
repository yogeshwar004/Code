# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import load_boston
import warnings
warnings.filterwarnings("ignore")

#dat=fetch_california_housing()
#dat=fetch_california_housing(as_frames=True)
dat=load_boston()
#print(dat)
Y=dat.target
#print(y)
df=pd.DataFrame(dat.data,columns=dat.feature_names)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
X=df[['INDUS']]
#split the data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
lg=LinearRegression()
lg.fit(X_train,Y_train)#Completed Model training
y_pred=lg.predict(X_test)
#lg.predict(X_test)
# Out:
# array([27.42030934, 25.95277834, 12.68903416, 23.21670359, 18.6835252 ,
#        21.96059654, 23.78257359, 16.3267699 , 18.6835252 , 23.91315898,
#        21.30145126, 25.04489899, 18.6835252 , 21.96059654, 25.34959822,
#        18.6835252 , 13.98866967, 18.6835252 , 29.6526976 , 18.6835252 ,
#        25.61076899, 25.95277834, 24.87700349, 22.5202482 , 18.6835252 ,
#        18.6835252 , 21.96059654, 18.6835252 , 23.35350733, 23.91315898,
#        27.42030934, 25.34959822, 18.6835252 , 18.6835252 , 18.6835252 ,
#        17.76320915, 25.54236712, 26.71141724, 23.35350733, 23.21670359,
#        23.91315898, 28.5831411 , 28.27222352, 26.16420229, 27.81828385,
#        18.6835252 , 24.87700349, 23.21670359, 18.6835252 , 28.50230253,
#        25.04489899, 27.86803066, 24.87700349, 24.61583272, 27.47005615,
#        18.6835252 , 18.6835252 , 26.86065768, 27.14670186, 26.29478768,
#        26.74872735, 29.18010287, 26.08336372, 24.87700349, 28.88784034,
# ...

# %%
#plotting the results
plt.scatter(X_test,Y_test,color="blue")
plt.plot(X_test['INDUS'],y_pred,color='red')
plt.title('Linear Regression')
plt.show()
